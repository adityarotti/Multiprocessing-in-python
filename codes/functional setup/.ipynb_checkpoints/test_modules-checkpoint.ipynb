# %%
from modules import power_serial as sp
from modules import power_function as pf
import healpy as h
import time

# %%
global nside=8 ; discsize=5. ; nprocs=4

lmin=2 ; lmax=3*nside
ell=np.linspace(lmax,lmax,lmax-lmin+1) ; cl=ell**-2.5
np.random.seed(0) ; data=h.synfast(cl,nside,verbose=False)

# %% [markdown]
# #Serial

# %%
t1=time.time()
fn=sp.power_serial(nside,discsize,nprocs)
fn.run(data)
print (time.time()-t1)
h.mollview(fn.power)
# Out:
# 0.0234310626984

# %% [markdown]
# # Python multiprocessing pool

# %%
pf.return_avg_power(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e262f502ad0b> in <module>()
# ----> 1 pf.return_avg_power(0)
#
# /Users/adityarotti/Documents/Work/github/Multiprocessing-in-python/codes/using_classes/modules/power_function.py in return_avg_power(cpixel)
#       8
#       9 def return_avg_power(cpixel):
# ---> 10         spixel=return_pixels_in_disc(cpixel)
#      11         return np.sum(data[spixel]**2.)/float(np.size(spixel))
#      12
#
# /Users/adityarotti/Documents/Work/github/Multiprocessing-in-python/codes/using_classes/modules/power_function.py in return_pixels_in_disc(cpixel)
#       3
#       4 def return_pixels_in_disc(cpixel):
# ----> 5         v=h.pix2vec(nside,cpixel)
#       6         spixel=h.query_disc(nside,v,discsize*np.pi/180.,inclusive=True,fact=4)
#       7         return spixel
#
# NameError: global name 'nside' is not defined

# %%
#t1=time.time()
fnpool=mpool.power_mppool(nside,discsize,nprocs,data)
#fnpool.run()
#print (time.time()-t1)
#h.mollview(fn.power)

# %%
import multiprocessing as mp
p=mp.Pool(processes=4)

# %%
p.map(fnpool.return_avg_power,arange(h.nside2npix(nside)))
