# %%
from modules import return_power as rp
import healpy as h
import time
# %matplotlib notebook
from matplotlib import cm
import matplotlib.pyplot as plt

cmap=cm.jet ; cmap.set_over(cmap(1.0)); cmap.set_under('w') ; cmap.set_bad('gray')

# %%
rp.init_param(128,2.)
rp.gen_data(11)

# %%
t1=time.time()
ys=rp.return_power_serial()
print (time.time()-t1)
h.mollview(ys,cmap=cmap)
# Out:
# 6.14998602867
# <img src="data:image/png;base64,..." width="850">

# %%
t1=time.time()
yp1=rp.return_power_mppool(16)
print (time.time()-t1)
h.mollview(yp1,cmap=cmap)
# Out:
# 4.35181522369
# <img src="data:image/png;base64,..." width="850">

# %%
t1=time.time()
yp2=rp.return_power_pr_shrdmem(16)
print (time.time()-t1)
h.mollview(yp2,cmap=cmap)
# Out:
# 2.93968200684
# <img src="data:image/png;base64,..." width="850">
